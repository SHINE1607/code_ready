# %%
import os 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Linear SVC

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
def linear_svc(data, target):
    sc = StandardScaler()
    data = sc.fit_transform(data)
    svclassifier = SVC(kernel='linear')
    svclassifier.fit(data, target)
    return [sc, svclassifier]

# %%
[scaler, svc_classifier] = linear_svc(X_train, y_train)
X_test = scaler.transform(X_test)
y_pred = svc_classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot = True)
ac = accuracy_score(y_pred,y_test)
ac

# %% [markdown]
# # Decision Tree

# %% [markdown]
#  Each node is assigned a feature, so that the model has maximum entropy
# * So the entropy measures the purity of the split. Purity is how purely the split happened between the chiled nodes.
# * entropy = measure of purity = H(S) = -p(+)*log(p(+)) - p(-)*log(p(-))
# * p(+)/p(-) = % of positive class/% of negative class
#
# We are trying to find the split having least entropy
# entropy = 1(worst) and entropy = 0 (best split)

# %% [markdown]
# Now we need to integrate all thses nodes to come with the best deciosn tree - answer to this **information gain**

# %%
from IPython.display import Image

Path = "../images/"
Image(filename = Path + "information_gain.png", width = 1000, height=100)

# %% [markdown]
# Tv ==> number of samples in that split
# <br>
# T ==> number of samples in the parent node
# <br>
# A ==> all child nodes
#
# **Higher the information gain better the split**

# %%
from sklearn.tree import DecisionTreeClassifier


def decision_tree_classifier(data, target):
    model1 = DecisionTreeClassifier(criterion)
    model1.fit(data,target)

    model2 = DecisionTreeClassifier(criterion)
    model2.fit(data, target)

# %%
[model_entropy, model_gini] = decision_tree_classifier(data, target)
y_pred1 = model_entropy.predict(X_test)
y_pred2 = model_entropy.predict(X_test)
